# %%
from sklearn.ensemble import RandomForestClassifier

X = merged_df.drop('dengue', axis=1)
X = X.select_dtypes(include=['int64','float64'])

y = merged_df['dengue']

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)

rf.fit(X, y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
importance = pd.Series(rf.feature_importances_, index=X.columns)

importance = importance.sort_values(ascending=False)

print(importance)
# Out:
# humidity                                 0.184338
# rainfall                                 0.168440
# min                                      0.165789
# month_x                                  0.143447
# max                                      0.136572
# year                                     0.123053
# reanalysis_tdtr_k                        0.006972
# reanalysis_air_temp_k                    0.006484
# reanalysis_relative_humidity_percent     0.006383
# weekofyear                               0.005695
# station_diur_temp_rng_c                  0.004574
# reanalysis_avg_temp_k                    0.004395
# station_min_temp_c                       0.004264
# station_avg_temp_c                       0.004149
# reanalysis_min_air_temp_k                0.004026
# reanalysis_max_air_temp_k                0.003973
# ndvi_ne                                  0.003418
# reanalysis_precip_amt_kg_per_m2          0.003247
# ndvi_nw                                  0.002910
# reanalysis_specific_humidity_g_per_kg    0.002891
# reanalysis_dew_point_temp_k              0.002801
# ndvi_se                                  0.002139
# station_precip_mm                        0.002100
# reanalysis_sat_precip_amt_mm             0.002065
# ndvi_sw                                  0.002061
# station_max_temp_c                       0.001948
# precipitation_amt_mm                     0.001866
# dtype: float64

# %%
importance = pd.Series(rf.feature_importances_, index=X.columns)
importance = importance.sort_values(ascending=False)

print(importance)
# Out:
# humidity                                 0.184338
# rainfall                                 0.168440
# min                                      0.165789
# month_x                                  0.143447
# max                                      0.136572
# year                                     0.123053
# reanalysis_tdtr_k                        0.006972
# reanalysis_air_temp_k                    0.006484
# reanalysis_relative_humidity_percent     0.006383
# weekofyear                               0.005695
# station_diur_temp_rng_c                  0.004574
# reanalysis_avg_temp_k                    0.004395
# station_min_temp_c                       0.004264
# station_avg_temp_c                       0.004149
# reanalysis_min_air_temp_k                0.004026
# reanalysis_max_air_temp_k                0.003973
# ndvi_ne                                  0.003418
# reanalysis_precip_amt_kg_per_m2          0.003247
# ndvi_nw                                  0.002910
# reanalysis_specific_humidity_g_per_kg    0.002891
# reanalysis_dew_point_temp_k              0.002801
# ndvi_se                                  0.002139
# station_precip_mm                        0.002100
# reanalysis_sat_precip_amt_mm             0.002065
# ndvi_sw                                  0.002061
# station_max_temp_c                       0.001948
# precipitation_amt_mm                     0.001866
# dtype: float64

# %%
top_features = [
    'humidity',
    'rainfall',
    'min',
    'max',
    'month_x',
    'year',
    'reanalysis_tdtr_k',
    'reanalysis_air_temp_k',
    'reanalysis_relative_humidity_percent',
    'ndvi_ne'
]

# %%
feature_selected_df = merged_df[top_features + ['dengue']]
feature_selected_df.to_csv("master.csv", index=False)

# %%
data=pd.read_csv("master.csv")
data
# Out:
#       humidity  rainfall   min   max  month_x  year  reanalysis_tdtr_k  \
# 0         78.8      39.9  10.2  25.1        1  2008           3.128571
# 1         78.8      39.9  10.2  25.1        1  2008           2.571429
# 2         78.8      39.9  10.2  25.1        1  2008           4.428571
# 3         78.8      39.9  10.2  25.1        1  2008           4.342857
# 4         78.8      39.9  10.2  25.1        1  2008           3.542857
# ...        ...       ...   ...   ...      ...   ...                ...
# 4987      79.8       0.4  10.5  26.5       12  2013          10.100000
# 4988      79.8       0.4  10.5  26.5       12  2013           9.657143
# 4989      79.8       0.4  10.5  26.5       12  2013           7.385714
# 4990      79.8       0.4  10.5  26.5       12  2013           8.228571
# 4991      79.8       0.4  10.5  26.5       12  2013          11.542857
#
#       reanalysis_air_temp_k  reanalysis_relative_humidity_percent   ndvi_ne  \
# 0                298.492857                             78.781429 -0.018900
# 1                298.475714                             78.230000 -0.018000
# 2                299.455714                             78.270000 -0.001500
# 3                299.690000                             73.015714       NaN
# 4                299.780000                             74.084286  0.056800
# ...                     ...                                   ...       ...
# 4987             297.774286                             89.990000  0.301471
# 4988             297.167143                             93.891429  0.247600
# 4989             295.831429                             94.967143  0.238729
# 4990             295.778571                             89.057143  0.310429
# 4991             297.372857                             87.030000  0.339467
#
#       dengue
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 4987      53
# 4988      53
# 4989      53
# 4990      53
# 4991      53
#
# [4992 rows x 11 columns]
